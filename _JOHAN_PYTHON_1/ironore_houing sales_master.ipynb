# %% [markdown]
# # Changes made from Class Tutorial and lesson solved codes-for a start

# %%
# !pip install matplotlib --upgrade
# Out:
# ...
# ERROR: pyviz 0.10.3 has requirement ipython<=7.1.1,>=5.4.0, but you'll have ipython 7.31.1 which is incompatible.
# ERROR: pyviz 0.10.3 has requirement matplotlib==3.0.3, but you'll have matplotlib 3.5.3 which is incompatible.
# ERROR: pyviz 0.10.3 has requirement pandas<0.25.0,>=0.23.4, but you'll have pandas 1.0.5 which is incompatible.
#   Using cached matplotlib-3.5.3-cp37-cp37m-win_amd64.whl (7.2 MB)
# ...
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.0.3
#     Uninstalling matplotlib-3.0.3:
#       Successfully uninstalled matplotlib-3.0.3
# ...

# %%
# Dependencies and Setup
import gmaps
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import matplotlib
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20)

# %%
#load  JOhan All housing data FILE  headers and spelling check FILE  headers and spelling check
Johan_ironore_metadata = "IRON-ORE-JOHAN_1.csv"
Johan_ironore_data = pd.read_csv(Johan_ironore_metadata)
NEWDATA=Johan_ironore_data.dropna(axis ='columns')
NEWDATA_df = pd.DataFrame(NEWDATA)
NEWDATA_df.to_csv("IORN ORE PRICE.csv", index = False)
NEWDATA_df.head()
# Out:
#       Date    IRON    GOLD  COFFEE   TEA  HOUSE PRICE  UNITS SOLD  DATEVALUE
# 0  2007M01   78.20  631.17    2.75  1.79      7334500           9      39083
# 1  2007M02   82.66  664.75    2.69  1.78      5957500           9      39114
# 2  2007M03   88.55  654.90    2.58  1.77     11498000          13      39142
# 3  2007M04   91.26  679.37    2.53  1.98      7266000           9      39173
# 4  2007M05  102.02  667.31    2.50  1.94      7391500          10      39203

# %%
y = NEWDATA_df["IRON"]
x1 = NEWDATA_df["Date"]
fig = plt.figure()
ax = fig.add_axes([0,0,4,4])
l1 = ax.plot(x1,y,'gs-') 
ax.set_xlabel('TIME',fontsize=24)
ax.set_ylabel('Price',fontsize=24)
plt.xticks(tick_locations, NEWDATA_df["Date"],fontsize=1, rotation="vertical")
plt.savefig(f'IRON ORE PRICE vs DATE.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17640\1045118669.py in <module>
#       6 ax.set_xlabel('TIME',fontsize=24)
#       7 ax.set_ylabel('Price',fontsize=24)
# ----> 8 plt.xticks(tick_locations, NEWDATA_df["Date"],fontsize=1, rotation="vertical")
#       9 plt.savefig(f'IRON ORE PRICE vs DATE.png')
#      10 plt.show()
#
# NameError: name 'tick_locations' is not defined

# %%
y = NEWDATA_df["UNITS SOLD"]
x1 = NEWDATA_df["Date"]
fig = plt.figure()
ax = fig.add_axes([0,0,4,4])
l1 = ax.plot(x1,y,'rd-')
ax.set_xlabel('DATE')
ax.set_ylabel('UNITS SOLD')
plt.savefig(f'UNITS SOLD vs DATA.png')
plt.show()

# %%
x = NEWDATA_df["Date"]
y = NEWDATA_df["IRON"]
y1 = NEWDATA_df["UNITS SOLD"]
#fig = plt.figure(figsize=(100,100))
#ax = fig.add_axes([0,0,4,2])
fig.suptitle('IRON Price vs. Sold Houses', fontsize=36, fontweight='bold')
fig, ax = plt.subplots(figsize=(50,30))
ax2 = ax.twinx()
l1 = ax.plot(x,y,'ys-',linewidth=7.0) 
#l2 = ax.plot(x,y1,'go--') 
ax2.plot(x,y1, color='red',linewidth=12.0)
#ax.plot(x, y1, c='b', label='y1',linewidth=7.0)
ax2.tick_params(axis='y', labelcolor='green')
ax.legend(labels = ('IRON PRICE'), loc = 'lower right')
ax2.legend(labels = ('UNITS SOLD'), loc = 'lower right') 
ax.set_title("IRON ORE PRICE IMPACT ON NUMBER OF HOUSE SOLD")
ax.set_xlabel('DATES')
ax.set_ylabel('UNITS')
plt.savefig(f'IRON Price vs UNITS SOLD.png')
plt.show()

# %%
def linearRegression(x_values,y_values,regEQplotX,regEQplotY,y_label):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    print(f'The r-square is {rvalue}')
    print(line_eq)
    plt.annotate(line_eq,(regEQplotX,regEQplotY),fontsize=15,color="red")
    plt.xlabel('Latitude')
    plt.ylabel(f'{y_label}')
    plt.grid()

# %%
#!pip install matplotlib --upgrade

# %%
x_values = NEWDATA_df["DATEVALUE"]
y_values = NEWDATA_df["IRON"]
m, b, *_ = stats.linregress(x_values, y_values)
plt.axline(xy1=(0,b), slope=m, label=f'$y = {m:.1f}x {b:+.1f}$')
#y = -0.01x + 345.99
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17640\3211079664.py in <module>
#       1 x_values = NEWDATA_df["DATEVALUE"]
#       2 y_values = NEWDATA_df["IRON"]
# ----> 3 m, b, *_ = stats.linregress(x_values, y_values)
#       4 plt.axline(xy1=(0,b), slope=m, label=f'$y = {m:.1f}x {b:+.1f}$')
#       5 #y = -0.01x + 345.99
#
# NameError: name 'stats' is not defined

# %%
#set the data sets to compare
x_values = NEWDATA_df["DATEVALUE"]
y_values = NEWDATA_df["IRON"]
regEQplotX = 0
regEQplotY = 0
#label the y axis
y_label = "Date"
#give the title
plt.title(f'Price')
linearRegression(x_values,y_values,regEQplotX,regEQplotY,y_label)
plt.savefig(f'IRON ORE vs TIME Regression.png')
plt.show()
# Out:
# The r-square is -0.21957106925990091
# y = -0.01x + 345.99

# %%
#Code from Lessons MATPLOT and PANDA's
x = NEWDATA_df["DATEVALUE"]
y = NEWDATA_df["UNITS SOLD"]
plt.scatter(x,y)
plt.grid()
#add titles and axis labels
plt.title(f"UNIST SOLD vs DATE")
plt.xlabel("DATE")
plt.ylabel("# UNITS")
#export as png
plt.savefig(f'UNIST vs TIME Regression.png')
plt.show()

# %%
#set the data sets to compare
x_values = NEWDATA_df["DATEVALUE"]
y_values = NEWDATA_df["UNITS SOLD"]
fig = plt.figure(figsize=(10,10))
regEQplotX = 0
regEQplotY = 0
#label the y axis
y_label = "Date"
#give the title
plt.title(f'Price')
linearRegression(x_values,y_values,regEQplotX,regEQplotY,y_label)
plt.savefig(f'HOUSE Sold vs TIME Regression.png')
plt.show()
# Out:
# The r-square is 0.9273071315027411
# y = 0.11x + -4223.36

# %%
locations = Johan_housingdf[['LATITUDE', 'LONGITUDE']]
weights = Johan_housingdf['PRICE']
PRINTMAP=locations.dropna(subset=['LATITUDE', 'LONGITUDE'])
fig = gmaps.figure(map_type='HYBRID')
fig = gmaps.figure(center=(48.0, 0.0), zoom_level=2)
fig
fig.add_layer(gmaps.heatmap_layer(PRINTMAP, weights=None))
fig
figure_layout = {'width': '500px', 'margin': '0 auto 0 auto'}
gmaps.figure(layout=figure_layout)
fig
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17640\6440850.py in <module>
# ----> 1 locations = Johan_housingdf[['LATITUDE', 'LONGITUDE']]
#       2 weights = Johan_housingdf['PRICE']
#       3 PRINTMAP=locations.dropna(subset=['LATITUDE', 'LONGITUDE'])
#       4 fig = gmaps.figure(map_type='HYBRID')
#       5 fig = gmaps.figure(center=(48.0, 0.0), zoom_level=2)
#
# NameError: name 'Johan_housingdf' is not defined

# %%
#test as aBARCHART
x_axis = np.arange(len(NEWDATA_df))
tick_locations = [value for value in x_axis]
plt.figure(figsize=(16,5))
plt.bar(x_axis, NEWDATA_df["UNITS SOLD"], color='r', alpha=1, align="center")
plt.xticks(tick_locations, NEWDATA_df["Date"],fontsize=1, rotation="vertical")
plt.savefig(f'BAR CHART IRON ORE vs TIME Regression.png')

# %%
# load  JOhan All housing data FILE  headers and spelling check
Johan_Housing_metadata = "JOhan All housing data.csv"
Johan_housing_data = pd.read_csv(Johan_Housing_metadata)
Johan_housingdf = pd.DataFrame(Johan_housing_data)
Johan_housingdf.head()
# Out:
#           Unnamed: 0 Column Labels Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                NaN  Sum of PRICE        NaN        NaN        NaN
# 1         Row Labels     2007\rM01  2007\rM02  2007\rM03  2007\rM04
# 2  Alexander Heights           NaN        NaN        NaN        NaN
# 3        Alfred Cove           NaN        NaN        NaN        NaN
# 4            Alkimos           NaN        NaN        NaN        NaN
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 329  \
# 0        NaN        NaN        NaN        NaN        NaN  ...          NaN
# 1  2007\rM05  2007\rM06  2007\rM07  2007\rM08  2007\rM09  ...    2020\rM05
# 2        NaN        NaN        NaN        NaN        NaN  ...          NaN
# 3        NaN        NaN        NaN        NaN        NaN  ...          NaN
# 4        NaN        NaN        NaN        NaN        NaN  ...            1
#
#   Unnamed: 330 Unnamed: 331 Unnamed: 332 Unnamed: 333 Unnamed: 334  \
# ...

# %%
# load KAGGEL FILE  headers and spelling check
kaggle_Housing_metadata = "all_perth_310121.csv"
kaggle_housing_data = pd.read_csv(kaggle_Housing_metadata)
kaggle_housingdf = pd.DataFrame(kaggle_housing_data)
kaggle_housingdf.head()
# Out:
#           Row Labels  Sum of PRICE
# 0  Alexander Heights   $58,020,500
# 1        Alfred Cove  $100,810,388
# 2            Alkimos   $47,167,478
# 3           Anketell   $19,166,500
# 4         Applecross  $108,758,500
